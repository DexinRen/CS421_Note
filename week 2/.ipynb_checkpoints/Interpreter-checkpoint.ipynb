-- %% [markdown]
-- ### Parts of an Interpreter
-- - The Parser
--     - Converts your ASCII input into an abstract syntax tree
-- - The evaluator
--     - Processes the abstract syntax tree to yield a result
--     - A type to represent values
--     - A function to evaluate the expressions into values (eval)
-- - An environment to keep track of the values of variables
-- - A top-level function to tie all this together: the REPL
--     - Read
--     - Eval
--     - Print
--     - Loop

-- %% [markdown]
-- ### Define the Types - Types.hs

-- %%
data Exp = IntExp Integer
    deriving (Show, Eq)

data Val = IntVall Integer
    deriving (Show, Eq)
    
type Env = [(String, Val)]
-- Out:
-- Line 1: Use newtype instead of data
-- Found:
-- data Exp
--   = IntExp Integer
--   deriving (Show, Eq)
-- Why not:
-- newtype Exp
--   = IntExp Integer
--   deriving (Show, Eq)Line 4: Use newtype instead of data
-- Found:
-- data Val
--   = IntVall Integer
--   deriving (Show, Eq)
-- Why not:
-- newtype Val
--   = IntVall Integer
--   deriving (Show, Eq)
